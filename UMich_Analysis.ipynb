# %% [markdown]
# # Topic Modeling Lab
# ## Contents
# 1. [Setup](#Section-1%3A-Setup)
#     1. [Import](#1.1-Import-Packages)
#     1. [Download](#1.2-Download-and-Prepare-Data)
#     1. [Read](#1.3-Read-Data)
#     1. [Pick Your Data](#1.4-Pick-Your-Data)
#     1. [Clean Text](#1.5-Clean-Text)
# 1. [Converting Text to Numbers](#Section-2%3A-Converting-Text-to-Numbers)
# 1. [LDA Topic Model](#Section-3%3A-LDA-Topic-Model)
# 1. [Interpret Topics](#Section-4%3A-Interpret-Topics)
# 1. [Topic Quality](#Section-5%3A-Topic-Quality)
# 1. [Topic Popularity](#Section-6%3A-Topic-Popularity)
# 1. [NMF Topic Model](#Section-7%3A-NMF-Topic-Model)
# 1. [What We Learned](#Section-7%3A-What-We-Learned)
#
# ## Section 0: Background
# - In this lab, we'll learn about topic modeling. Topic modeling uses statistics to understand what text is about, that is, to find the topics in text.
# - We'll use the online dating profile text that OKCupid made public as our example, but of course topic modeling can be used on any text.
#
# @Author: [Jeff Lockhart](http://www-personal.umich.edu/~jwlock/) & [Ed Platt](https://elplatt.com/), with some code adapted from [Aneesha Bakharia](https://medium.com/@aneesha/topic-modeling-with-scikit-learn-e80d33668730)'s example.

# %% [markdown]
# ## Section 1: Setup
# ### 1.1 Import Packages
# - Packages contain code others have written to make our work easier.

# %%
import pandas as pd
import numpy as np
import pickle
#from tqdm import tqdm
#tqdm.pandas()
from scipy.stats.stats import pearsonr  
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.metrics.pairwise import cosine_similarity
#from bs4 import BeautifulSoup
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1.2 Download and Prepare Data
# This code checks whether you have the data. If you don't, it will download and prepare it for you. To see how it works, look at lab `1 Data munging` which explains it in detail.

# %%
#%run -i 'download_and_clean_data.py'
#print('Ready to go!')

# %% [markdown]
# ### 1.3 Read Data

# %%
seed = 2019

# %%
profiles = pd.read_csv('final_okcupid.csv').dropna(subset=['essay0'])
profiles.head(2)
# Out:
#    new_index  orig_index  age  \
# 0          0           0   22
# 1          1           3   23
#
#                                               essay0  \
# 0  about mei would love to think that i was some ...
# 1             i work in a library and go to school
#
#                                               essay9  height  \
# 0  you want to be swept off your feet!you are tir...      75
# 1                              you feel so inclined.      71
#
#                    edu      fit race_ethnicity height_group  long_words  \
# 0  High School or less  not_fit       multiple    not_short          17
# 1  High School or less  not_fit          White    not_short           0
#
#      flesch  dbscan_cluster  profile_length  prop_longwords
# 0  5.837333               1             231        0.073593
# 1  1.031111               1               9        0.000000

# %%
pd.crosstab(index=profiles['edu'],  # Make a crosstab
                        columns="count")
# Out:
# col_0                  count
# edu
# High School or less     3214
# More than High School  13577
# unknown                 2026

# %%
pd.crosstab(index=profiles['fit'],  # Make a crosstab
                        columns="count")
# Out:
# col_0    count
# fit
# fit      10538
# not_fit   8228
# unknown     51

# %%
pd.crosstab(index=profiles['race_ethnicity'],  # Make a crosstab
                        columns="count")
# Out:
# col_0           count
# race_ethnicity
# Asian            2659
# Black             640
# Latinx           1728
# White           11722
# multiple         1335
# other             733

# %%
pd.crosstab(index=profiles['height_group'],  # Make a crosstab
                        columns="count")
# Out:
# col_0         count
# height_group
# not_short     12201
# short          6616

# %% [markdown]
# ### 1.4 Pick Your Data
# - Pick which section of the profiles you want to analyze.
# #### Options:
# - `text` - All of the text from a profile (**Recommended**)
# - `essay0` - My self summary (**Recommended**)
# - `essay1` - What I’m doing with my life
# - `essay2` - I’m really good at
# - `essay3` - The first thing people usually notice about me
# - `essay4` - Favorite books, movies, show, music, and food
# - `essay5` - The six things I could never do without
# - `essay6` - I spend a lot of time thinking about
# - `essay7` - On a typical Friday night I am
# - `essay8` - The most private thing I am willing to admit
# - `essay9` - You should message me if...
#
# #### Replace `essay0` in the cell below with the essay you want to look at.
# - `text` and `essay0` are both recommended, but it's your choice.

# %%
profile_section_to_use = 'essay0'

# %%
documents = profiles[profile_section_to_use]

# %% [markdown]
# ### 1.5 Clean Text
# - For this lab, it is not so important that you understand this code.
# - For now, just run it and move on.

# %% [markdown]
# ## Section 2: Converting Text to Numbers
# - Our first model takes "count vectors" as input, that is, a count of how many times each word shows up in each document.
#     - Here we tell it to only use the 1,000 most popular words, ignoring stop words like "a" and "of".
#     - We use the abbreviation `tf` for these because they represent "text frequency," i.e., how often each word shows up in text.

# %%
profiles
# Out:
#        new_index  orig_index  age  \
# 0              0           0   22
# 1              1           3   23
# 2              2           5   29
# 3              3           9   37
# 4              4          11   28
# 5              5          16   33
# 6              6          18   31
# 7              7          19   33
# 8              8          22   30
# 9              9          23   30
# 10            10          24   33
# 11            11          25   28
# 12            12          26   22
# 13            13          36   32
# 14            14          39   35
# 15            15          41   35
# 16            16          43   40
# 17            17          52   31
# 18            18          56   26
# 19            19          57   21
# 20            20          60   31
# 21            21          65   29
# 22            22          66   22
# 23            23          72   35
# 24            24          74   28
# 25            25          76   26
# 26            26          79   21
# 27            27          82   34
# 28            28          85   28
# 29            29          90   24
# ...          ...         ...  ...
# 18787      18801       60389   26
# 18788      18802       60390   41
# 18789      18803       60392   29
# 18790      18804       60398   25
# 18791      18805       60401   26
# 18792      18806       60405   33
# 18793      18807       60419   42
# 18794      18808       60438   24
# 18795      18809       60439   24
# 18796      18810       60444   33
# 18797      18811       60445   48
# 18798      18812       60465   31
# 18799      18813       60466   51
# 18800      18814       60472   29
# 18801      18815       60474   32
# 18802      18816       60478   33
# 18803      18817       60481   19
# 18804      18818       60484   25
# 18805      18819       60486   25
# 18806      18820       60498   30
# 18807      18821       60500   32
# 18808      18822       60513   24
# 18809      18823       60523   26
# 18810      18824       60529   22
# 18811      18825       60534   29
# 18812      18826       60535   27
# 18813      18827       60537   24
# 18814      18828       60548   24
# 18815      18829       60549   42
# 18816      18830       60550   27
#
#                                                   essay0  \
# 0      about mei would love to think that i was some ...
# 1                 i work in a library and go to school
# 2      i'm an australian living in san francisco but ...
# 3      my names jakei'm a creative guy and i look for...
# 4      i was born in wisconsin grew up in iowa and mo...
# 5      i just moved to the bay area from austin tx or...
# 6      some of my favorite things riding my motorcycl...
# 7      i relocated to san francisco half a year ago t...
# 8      i tend to think the same way a comedian does a...
# 9      here's a completely fake summary i wrote while...
# 10     bay area transplant six years or so now straig...
# 11     hey to all hope all is well and your having a ...
# 12     fulltime student fulltime square i change from...
# 13     i lost a needle in a haystack once and found i...
# 14     i love life oh ok cupid is telling me that thr...
# 15     i grew up in new york and san diego half and h...
# 16     i don't really like summarizing myself but who...
# 17       i'm a free culture nerd i travel talk and teach
# 18     originally from france lived in 3 different co...
# 19     i grew up in iowa it gets a bad rap but let me...
# 20     straight to the point i sugar coat but i mean ...
# 21     i really like meeting new people small world n...
# 22     it will be way too boring to just reveal yours...
# 23     i'm an adventurer first i take calculated risk...
# 24     i can be extrovert and charming and yet enjoy ...
# 25     raised by a sailor and a taxidermist in the pa...
# 26     originally from southern california moved up t...
# 27     i moved to sf 7 months ago and so far i'm real...
# 28     like everyone else on this site i feel awkward...
# 29              mmm mmm i dk what to say so just ask me
# ...                                                  ...
# 18787  went to college in colorado went to san diego ...
# 18788  i am spending the next two years pursuing my l...
# 18789  i live in san francisco and if you're reading ...
# 18790                                    to be continued
# 18791  i'm a passionate guy that likes to engage in g...
# 18792  i love trying new restaurants jogging hiking t...
# 18793  grew up in chicago moved here in 1989i'm a thi...
# 18794  my name is troy and i was born and raised in n...
# 18795  i'm very friendly and i try to be outgoing and...
# 18796  hi i'm dan thanks for taking the time to check...
# 18797  i'm a seasoned seeker i've been a working musi...
# 18798  a random character in the abyss born in sf rai...
# 18799  i have had my fair share of adventures and int...
# 18800  according to myers briggs typology i'm an in t...
# 18801  you can call me to i chase dough a roller i am...
# 18802  lazy hard worker over thinker and good mate i ...
# 18803  would you describe yourself as a very attracti...
# 18804  i like to try new things i love going to new p...
# 18805  i'm really into dancing salsa  ballroom i like...
# 18806  i'm both sarcastic and sweet i love seeing liv...
# 18807  i try to lose my mind so i can come to my sens...
# 18808  my name is peter i'm an oakland native and i s...
# 18809                          i am a master of mischief
# 18810  i like hanging out with friends and meeting ne...
# 18811  i'm here to perhaps meet new friends and to gi...
# 18812  i like iced tea old tv sets wearing brown clot...
# 18813  born in southern india grew up in dubai lived ...
# 18814  i'm nicki never know what to write about mysel...
# 18815  hello i enjoy traveling watching movies and ha...
# 18816  all i have in this world are my balls and my i...
#
#                                                   essay9  height  \
# 0      you want to be swept off your feet!you are tir...      75
# 1                                  you feel so inclined.      71
# 2                                        you're awesome.      67
# 3                                 you can rock the bells      65
# 4      if you know who you are, who you want, where y...      72
# 5      you want to help me assemble ikea stuff and/or...      70
# 6      because i'll try to write back, and it's hard ...      71
# 7                                     you wanna meet up.      72
# 8      you're a positive and creative personality loo...      69
# 9      you're nice, you've got integrity, and you can...      71
# 10     you like to mob around on bikes and make fun o...      73
# 11                 if you want to get to know me better.      70
# 12     if you don't mind chatting with a closet dork ...      72
# 13           you're awesomeyou're sexyyou're adventurous      69
# 14     you're participating in the human trials of th...      74
# 15     -you're graceful, grounded, sharp, kind, insig...      72
# 16     ...you're still reading. at least say hello.es...      71
# 17     you are interested in hanging out somewhere in...      69
# 18     you want to go on adventures, eat well and hav...      71
# 19     * you have a favorite npr personality* you can...      72
# 20     ...you have an open-mind....somewhat attracted...      67
# 21     you want to- check out a food pop-up- introduc...      68
# 22                              just say hi..i dont bite      65
# 23     you can make me laugh or turn me on.teach me s...      73
# 24     you read my profile in its entirety and are in...      72
# 25     you like to dance but hate going to the club, ...      72
# 26     if you are friendly and open to getting to kno...      71
# 27     if you love hiking/camping, traveling in 3rd-w...      69
# 28     you think outside the box, color outside the l...      68
# 29            you don't have anything else to do really.      74
# ...                                                  ...     ...
# 18787  if you'd like to message me go for it. i'll be...      71
# 18788  smell gas. i can help you locate the shutoff v...      67
# 18789  what i'm looking for is someone who also is as...      72
# 18790                                     keep it local.      70
# 18791                                 you're interested.      71
# 18792  you want someone kick-ass to explore the bay a...      74
# 18793                                             #NAME?      68
# 18794  if you think you would enjoy the company of an...      73
# 18795  if you read this far and something made you sm...      70
# 18796  * you love this song: ://youtu.be/coiic3a0rom*...      68
# 18797  ...you're interested in taking salsa lessons w...      61
# 18798     you're down to chill and have some good times.      74
# 18799  you like adventures far and near. you think we...      68
# 18800  * you've been dealing with men on this site wh...      68
# 18801                    u feel like treat'n yourself...      70
# 18802  you think we can have good time together :)rea...      73
# 18803  you would describe yourself as very attractive...      74
# 18804                                       you want to.      68
# 18805  if something i wrote looks interesting.you hav...      69
# 18806  "we need to make books cool again. if you go h...      72
# 18807  you want to change the world and know how. or ...      71
# 18808  you like guys who can dress and smell nice, co...      72
# 18809                     if you want to jump on my bed.      71
# 18810  you're a nerd, looking for another nerd, to do...      71
# 18811  a) just because you want.b) you think you'd li...      75
# 18812  if you want to get a reply that i think is wit...      68
# 18813  you're looking to make a new friend, online an...      72
# 18814     meh if you made it this far you might as well.      72
# 18815                         we have similar interests.      71
# 18816              you are interested and interesting...      73
#
#                          edu      fit race_ethnicity height_group  long_words  \
# 0        High School or less  not_fit       multiple    not_short          17
# 1        High School or less  not_fit          White    not_short           0
# 2      More than High School  not_fit          White        short          11
# 3                    unknown      fit          White        short           9
# 4      More than High School  not_fit          White    not_short          31
# 5      More than High School      fit          White    not_short          27
# 6                    unknown  not_fit          White    not_short           9
# 7      More than High School      fit          White    not_short          27
# 8      More than High School      fit          White        short           8
# 9      More than High School  not_fit          White    not_short           7
# 10     More than High School  not_fit          White    not_short          12
# 11     More than High School      fit       multiple    not_short          30
# 12       High School or less      fit       multiple    not_short           4
# 13     More than High School      fit          White        short           1
# 14     More than High School      fit          White    not_short          10
# 15     More than High School      fit       multiple    not_short           1
# 16     More than High School      fit          White    not_short          21
# 17     More than High School  not_fit          White        short           0
# 18       High School or less      fit          White    not_short          10
# 19       High School or less  not_fit          White    not_short          31
# 20       High School or less      fit          Asian        short           9
# 21     More than High School      fit          White        short           9
# 22       High School or less      fit          Asian        short           2
# 23                   unknown      fit       multiple    not_short          13
# 24     More than High School      fit          White    not_short          10
# 25     More than High School      fit          White    not_short           5
# 26       High School or less      fit          White    not_short           7
# 27     More than High School      fit          White        short          12
# 28     More than High School  not_fit          White        short          32
# 29     More than High School  not_fit          Black    not_short           1
# ...                      ...      ...            ...          ...         ...
# 18787  More than High School      fit          White    not_short           4
# 18788  More than High School  not_fit          White        short          20
# 18789  More than High School  not_fit          White    not_short          13
# 18790  More than High School  not_fit          White    not_short           1
# 18791  More than High School      fit          White    not_short          12
# 18792  More than High School      fit          White    not_short          10
# 18793  More than High School      fit          White        short           9
# 18794  More than High School  not_fit         Latinx    not_short          15
# 18795  More than High School  not_fit         Latinx    not_short          21
# 18796  More than High School      fit       multiple        short          32
# 18797                unknown  not_fit          White        short           9
# 18798  More than High School      fit          Black    not_short           1
# 18799  More than High School  not_fit          White        short          14
# 18800  More than High School  not_fit          White        short          10
# 18801  More than High School      fit          Black    not_short           4
# 18802  More than High School      fit          White    not_short           4
# 18803                unknown  not_fit          White    not_short           3
# 18804                unknown  not_fit          Asian        short           9
# 18805                unknown      fit          White        short          11
# 18806  More than High School  not_fit          White    not_short          12
# 18807                unknown  not_fit          White    not_short           3
# 18808  More than High School  not_fit          White    not_short           3
# 18809  More than High School      fit          White    not_short           0
# 18810                unknown  not_fit       multiple    not_short          10
# 18811  More than High School  not_fit         Latinx    not_short          11
# 18812  More than High School  not_fit          White        short           1
# 18813  More than High School      fit          Asian    not_short          12
# 18814    High School or less      fit       multiple    not_short           9
# 18815  More than High School  not_fit          Asian    not_short          15
# 18816    High School or less      fit       multiple    not_short           3
#
#           flesch  dbscan_cluster  profile_length  prop_longwords
# 0       5.837333               1             231        0.073593
# 1       1.031111               1               9        0.000000
# 2       6.323600               1             154        0.071429
# 3       3.179028               1             101        0.089109
# 4      10.697344               1             262        0.118321
# 5       6.902325               1             310        0.087097
# 6      28.821538               1              78        0.115385
# 7      18.572716               1             237        0.113924
# 8       9.402222               1              47        0.170213
# 9       4.876034               1             143        0.048951
# 10      6.442586               0             123        0.097561
# 11      8.912787               1             270        0.111111
# 12      4.759487               1              81        0.049383
# 13      1.542500               1              17        0.058824
# 14      5.455433               1             191        0.052356
# 15     15.449767               1              45        0.022222
# 16      9.504472               1             166        0.126506
# 17      0.500455               1              10        0.000000
# 18      7.441484               1              95        0.105263
# 19      5.688182               1             229        0.135371
# 20      3.047451               1             106        0.084906
# 21      8.263217               1              54        0.166667
# 22      5.163750               1              30        0.066667
# 23     10.201282               1             110        0.118182
# 24      8.825333               1              80        0.125000
# 25      5.636923               1              73        0.068493
# 26      8.201471               1              37        0.189189
# 27     15.348949               1             202        0.059406
# 28      8.228990               1             275        0.116364
# 29      3.653333               1              11        0.090909
# ...          ...             ...             ...             ...
# 18787   4.589333               1              61        0.065574
# 18788   8.006416               1             147        0.136054
# 18789   4.329405               1             235        0.055319
# 18790   5.246667               1               3        0.333333
# 18791   7.221611               1              95        0.126316
# 18792   5.462240               1             127        0.078740
# 18793   7.143835               1             110        0.081818
# 18794  10.356041               1             102        0.147059
# 18795   7.401786               1             232        0.090517
# 18796   8.262768               1             308        0.103896
# 18797   7.247940               1              70        0.128571
# 18798   1.727172               1              30        0.033333
# 18799  10.971037               1             114        0.122807
# 18800  10.535192               1              68        0.147059
# 18801   4.920203               1              45        0.088889
# 18802   3.030957               0              50        0.080000
# 18803   6.330323               1              31        0.096774
# 18804   7.964677               1              98        0.091837
# 18805   8.903690               1             150        0.073333
# 18806  11.231487               1              85        0.141176
# 18807   2.995588               1              53        0.056604
# 18808   6.064840               1              47        0.063830
# 18809   2.483333               1               6        0.000000
# 18810   9.083429               1              83        0.120482
# 18811  16.732927               1             174        0.063218
# 18812   6.137500               1              32        0.031250
# 18813   7.828889               1              95        0.126316
# 18814   4.492500               1              96        0.093750
# 18815   5.665455               1             172        0.087209
# 18816   7.658659               1              43        0.069767
#
# [18817 rows x 15 columns]

# %%
tf_vectorizer = CountVectorizer(max_features=2000, stop_words='english', ngram_range=(1,3))

print("Vectorizing text by word counts...")
tf_text = tf_vectorizer.fit_transform(profiles['essay0'])

tmp = tf_text.get_shape()
print("Our transformed text has", tmp[0], "rows and", tmp[1], "columns.")
# Out:
# Vectorizing text by word counts...
# Our transformed text has 18817 rows and 2000 columns.

# %% [markdown]
# #### See what words are being counted

# %%
tf_words = tf_vectorizer.get_feature_names()

print("The first few words (alphabetically) are:\n\n", tf_words[:500])
# Out:
# The first few words (alphabetically) are:
#
#  ['10', '10 years', '100', '12', '15', '20', '23', '25', '30', '500', 'ability', 'able', 'abroad', 'absolutely', 'absolutely love', 'absurd', 'accent', 'accept', 'achieve', 'act', 'action', 'active', 'activities', 'activity', 'actual', 'actually', 'add', 'addicted', 'admit', 'adult', 'advantage', 'adventure', 'adventures', 'adventurous', 'affectionate', 'afraid', 'africa', 'age', 'ago', 'agree', 'ahead', 'air', 'alive', 'amazing', 'ambitious', 'america', 'american', 'analytical', 'andi', 'angeles', 'animal', 'animals', 'answer', 'answers', 'anymore', 'apartment', 'apparently', 'appreciate', 'appreciation', 'approach', 'architecture', 'area', 'area native', 'area years', 'areas', 'aren', 'art', 'artist', 'artistic', 'arts', 'asia', 'asian', 'aside', 'ask', 'asked', 'aspects', 'ass', 'aswell', 'athlete', 'athletic', 'attempt', 'attend', 'attending', 'attention', 'attitude', 'attracted', 'attraction', 'attractive', 'australia', 'available', 'average', 'avid', 'avoid', 'aware', 'away', 'awesome', 'awhile', 'awkward', 'baby', 'background', 'backpacking', 'bad', 'balance', 'balanced', 'ball', 'band', 'bands', 'bar', 'bars', 'baseball', 'based', 'basically', 'basis', 'basketball', 'bass', 'bay', 'bay area', 'bay area native', 'bay area years', 'beach', 'beaches', 'bear', 'beat', 'beautiful', 'beauty', 'bed', 'beer', 'begin', 'beginning', 'beliefs', 'believe', 'berkeley', 'best', 'best friend', 'best way', 'better', 'bicycle', 'big', 'big fan', 'biggest', 'bike', 'bikes', 'biking', 'bit', 'black', 'blah', 'blah blah', 'blessed', 'blue', 'blues', 'board', 'board games', 'boat', 'body', 'bonus', 'book', 'books', 'bored', 'boring', 'born', 'born raised', 'born raised san', 'boston', 'bottle', 'bought', 'box', 'boy', 'boys', 'brain', 'break', 'briggs', 'bright', 'bring', 'brings', 'british', 'brother', 'brought', 'brown', 'bs', 'build', 'building', 'built', 'bunch', 'burning', 'burning man', 'business', 'busy', 'buti', 'buy', 'ca', 'cal', 'cali', 'california', 'called', 'calm', 'came', 'camp', 'camping', 'camping hiking', 'canada', 'cannon', 'car', 'card', 'care', 'career', 'caring', 'carry', 'cars', 'case', 'casual', 'cat', 'catch', 'cats', 'cause', 'center', 'central', 'certain', 'certainly', 'challenge', 'challenges', 'challenging', 'chance', 'change', 'changed', 'changing', 'character', 'charming', 'chat', 'check', 'checking', 'cheese', 'chef', 'chemistry', 'chicago', 'child', 'childhood', 'children', 'chill', 'china', 'chinese', 'chocolate', 'choice', 'choose', 'circle', 'cities', 'city', 'class', 'classes', 'classic', 'classical', 'clean', 'clear', 'clever', 'click', 'climb', 'climbing', 'close', 'close friends', 'clothes', 'club', 'clubs', 'coast', 'coffee', 'cold', 'college', 'color', 'colorado', 'com', 'come', 'comedy', 'comes', 'comfort', 'comfortable', 'comic', 'coming', 'committed', 'common', 'communication', 'community', 'companion', 'company', 'compassion', 'compassionate', 'competitive', 'complete', 'completely', 'complex', 'complicated', 'computer', 'computer science', 'computers', 'concert', 'concerts', 'confidence', 'confident', 'connect', 'connection', 'connections', 'conscious', 'consider', 'considerate', 'constant', 'constantly', 'construction', 'contact', 'content', 'continue', 'control', 'conversation', 'conversations', 'cook', 'cooking', 'cool', 'core', 'couch', 'couldn', 'count', 'countries', 'country', 'county', 'couple', 'couple years', 'course', 'crazy', 'cream', 'create', 'created', 'creating', 'creative', 'creativity', 'crime', 'cross', 'cruz', 'cultural', 'culture', 'cultures', 'cup', 'cupid', 'curiosity', 'curious', 'current', 'currently', 'currently working', 'cut', 'cute', 'cycling', 'cynical', 'dad', 'daily', 'damn', 'dance', 'dancing', 'dark', 'date', 'dates', 'dating', 'daughter', 'day', 'days', 'dc', 'dead', 'deal', 'death', 'decent', 'decide', 'decided', 'dedicated', 'deep', 'deeply', 'define', 'definitely', 'degree', 'degrees', 'delicious', 'dependable', 'depending', 'described', 'describing', 'desi ...

# %% [markdown]
# #### See an example of how a profile's text is encoded
# - `n` is the profile number you want to look at. Change the value of `n` and re-run the code to see different profiles.
# - Note that only some of the words are counted. This is because we set `max_features=1000` in the vectorizor function, so it is only counting the 1,000 most common words and ignoring the rest.
#     - You can change that number to be bigger or smaller and see what happens.
#     - We found in Lab 1 that 1,000 is a good choice for this data because words less popular than that show up in less than 1% of all profiles.

# %%
n = 6

def show_vector(x, words):
    rows,cols = x.nonzero()
    for row,col in zip(rows,cols):
        print(words[col], '\t', x[row,col].round(2))

print('Profile text:\n', documents[n])
print('\nTF (count) vector:')
show_vector(tf_text[n], tf_words)
# Out:
# Profile text:
#  some of my favorite things riding my motorcycle on curvy roads curling up with the next book in the series finding great photographs building things joking around with my friends finding funny moments the stars windy days living near the beach love and compassion music cooking dinner with a friend sometimes i'll take a different route just to see where it goes my photos are available on casebook for a peak of some of those unguarded moments p
#
# TF (count) vector:
# favorite things 	 1
# available 	 1
# photos 	 1
# goes 	 1
# dinner 	 1
# cooking 	 1
# compassion 	 1
# beach 	 1
# near 	 1
# stars 	 1
# moments 	 2
# building 	 1
# great 	 1
# finding 	 2
# series 	 1
# book 	 1
# motorcycle 	 1
# riding 	 1
# friends 	 1
# ll 	 1
# different 	 1
# music 	 1
# days 	 1
# living 	 1
# just 	 1
# funny 	 1
# things 	 2
# favorite 	 1
# friend 	 1
# love 	 1

# %% [markdown]
# ## Section 3: LDA Topic Model
#
# - LDA stands for Latent Dirichlet Allocation. The statistical math behind it is complicated, but its goals are simple:
#     - find groups of words that often show up together and call those groups topics.
#     - find topics that can be used to tell documents apart, i.e. topics that are in some documents but not others.
# - LDA is the most popular method for topic modeling.
# - [Learn more](https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation) about LDA
#
# ### Step 1: Decide how many topics we want to find
# - We must tell LDA how many topics we want it to look for (we did this above with the `ntopics` variable.

# %%
#how many topics we want our model to find
ntopics = 9

#how many top words we want to display for each topic
nshow = 40

# %% [markdown]
# ### Step 2: Run the LDA algorithm
# - LDA can be a little slow. We'll use a faster method later on.
# - Set `n_jobs=` to the number of processors you want to use to compute LDA. If you set it to `-1`, it will use all available processors.

# %%
model = LatentDirichletAllocation(n_components=ntopics, max_iter=10, 
                                  learning_method='online', n_jobs=2,
                                 random_state=seed)

print('Performing LDA on vectors. This may take a while...')
lda = model.fit(tf_text)
lda_topics = lda.components_

print('Done!')
# Out:
# Performing LDA on vectors. This may take a while...
# Done!

# %%
lda_topics.shape
#What do these dimensions mean?
# Out:
# (9, 2000)

# %%
filename = 'lda_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ## Section 4: Interpret Topics
# #### Some helper functions
# Don't worry about how these work right now. Just run them and scroll down. We'll use them to make our analysis easier later on.

# %%
def describe_topic(topic, feature_names, n_words=10):
    words = []
    # sort the words in the topic by importance
    topic = topic.argsort() 
    # select the n_words most important words
    topic = topic[:-n_words - 1:-1]
    # for each important word, get it's name (i.e. the word) from our list of names
    for i in topic:
        words.append(feature_names[i])
    # print the topic number and its most important words, separated by spaces
    return " ".join(words)

def display_topics(components, feature_names, n_words=40):
    # loop through each topic (component) in the model; show its top words
    for topic_idx, topic in enumerate(components):
        print("Topic {}:".format(topic_idx), 
              describe_topic(topic, feature_names, n_words))
    return

def find_intersection(idxa, idxb, n):
    a = set()
    b = set()
    both = set()
    i = 0
    while len(both) < n:
        a.add(idxa[i])
        b.add(idxb[i])
        both = a.intersection(b)
        i += 1
    return list(both)

def compare_topic_words(topics, a, b, words, how='overlap', n_words=nshow):
    b_sort = False
    if how == 'difference':
        b_sort = True
    
    dfa = pd.DataFrame(topics, columns=words).T
    idxa = dfa.sort_values(by=a, ascending=False).index.values
    idxb = dfa.sort_values(by=b, ascending=b_sort).index.values
    both = find_intersection(idxa, idxb, n=n_words)
    
    out = how + ' between ' + str(a) + ' and ' + str(b) + ':'
    for w in both:
        out += ' ' + w
    print(out)
    return

def blue_matrix(cells, xl, yl, x_labels=None):
    n = cells.shape[0]
    plt.figure()
    fig, ax = plt.subplots(figsize=(8,8))
    plt.imshow(cells, cmap='Blues')
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top') 
    if x_labels is not None:
        plt.xticks(range(n), x_labels)
    else:
        plt.xticks(range(n))
    plt.yticks(range(n))
    plt.ylabel(yl)
    plt.xlabel(xl)
    # show a colorbar legend
    plt.colorbar()
    #plt.title('Correlation between Topics', fontsize=25)
    plt.savefig('correl.png')
    return

# %% [markdown]
# ### Step 1: Show our topics with the top words in each

# %%
display_topics(lda_topics, tf_words, n_words=30)
# Out:
# Topic 0: love im just like good games bay time raised area born raised guy born music pretty play fun sports bay area playing laugh going fan laid know currently good time enjoy video moved bay
# Topic 1: like things ve don think really pretty ll just ok people read profile probably lot self make say stuff little geek bit thing actually way got doing random awesome good
# Topic 2: like know people just don want life good really looking think person time say make way right love things fun ll meet feel little need world women believe guy let
# Topic 3: enjoy good love like hiking looking fun outdoors movies watching sports active life biking camping activities woman relationship music old food healthy playing open wine intelligent great running honest conversation
# Topic 4: san francisco san francisco love city moved years like ago sf just year work travel years ago living live going ve music food new beach bike lived old moved san recently town places
# Topic 5: bay area years school bay area ve college went grew new lived east moved coast california sf year spent born work working berkeley recently east coast company living york new york city job
# Topic 6: love life music live world time friends people art enjoy ve things family travel living great passionate learning work experience creative new experiences rock important nature try make share different
# Topic 7: time like spend work friends lot night family day watch hard movie spend time movies free play home love lol just kinda friends family working free time watching dance crazy going good lot time
# Topic 8: new people things going like fun enjoy friends meet love looking easy try new things new people guy life humor sense person open sense humor good trying easy going meeting hard minded places open minded

# %%
# Topic Model Dictionary:
topic_names = {}

# %% [markdown]
# #### Short Answer:
# - Pick three topics.
# - Look at the words that make up each one. Say which one it is, and briefly answer these questions about it (3-5 sentences per topic):
#     - What does the topic seem to be about?
#     - If someone used most of those words together, what might they be talking about?
#     - Do any of the other topics seem similar to this one?

# %% [markdown]
# **Write your response here:**
# ....

# %% [markdown]
# ### Step 2: Examine the words that make two topics similar or different
# - We can also compare two topics to each other by looking at words that are common in both, or words that are common in one but not the other.
# - Try changing `topic_a` and `topic_b` to different topic numbers.
# - Notice the `how` option will let you see either the `overlap` or `difference` between two topics
#     - Notice also that the difference between topics a and b is not the same as between b and a

# %%
topic_a = 8
topic_b = 1

compare_topic_words(lda_topics, topic_a, topic_b, tf_words, how='overlap', n_words=nshow)
compare_topic_words(lda_topics, topic_a, topic_b, tf_words, how='difference', n_words=nshow)
compare_topic_words(lda_topics, topic_b, topic_a, tf_words, how='difference', n_words=nshow)
# Out:
# overlap between 8 and 1: kind different good really ones make personality humor funny like play interesting nice tend pretty work try enjoy just trying having smart sarcastic random doing making cooking things know going new friends recently learning guy usually love eat people cool
# difference between 8 and 1: fun loving going guy work hard play try new guy looking meeting new enjoy life looking new new people make new friends good sense humor work hard easy going great sense trying new willing try easy going guy good sense love meet explore new trying new things play hard guy likes make new try new things meet new people meeting new people love meeting great sense humor hard play hard meet new new things looking meet new places hard play exploring new new restaurants cultures family friends love travel
# difference between 1 and 8: picture wear damn terrible radio cat self summary computers don think board video child details public photos shit profiles word whiskey gonna dislike song cupid pizza section summary computer science wearing star attention history ok cupid apparently says hot sorry street didn took ice

# %% [markdown]
# ### Step 3: Interpret these topics
# #### Short Answer
# - This part is for you to do: code can't do it for you.
# - Try to come up with a short, catchy name for each topic and write it down.
#     - For example, if the words were "san francisco city moved living born years raised lived live", you might call it "places lived" because the topic seems to be about where people currently live (San Francisco) and where they were born / raised / moved from.

# %% [markdown]
# **Write your response here:**
# ...

# %% [markdown]
# ### Step 4: Check whether your interpretations match with the text
#
# #### Helper functions
# - Run this code and scroll down.
# - You don't need to understand these details right now.

# %%
def get_profiles_from_topics(data, transformed, topic_a, topic_b=None, pick_from=10):
    #get our data ready
    df = pd.DataFrame(transformed)
    df = df.sort_values(by=topic_a, ascending=False)
    n = df.shape[0]
    
    if topic_b is None:
        #if we only want things high in one topic, take randomly from the top
        keep = df.head(pick_from).sample(1)
        pid = keep.index.values[0]
    else:
        #if we want things high in two topics, find them and pick one of the top
        idxb = df.sort_values(by=topic_b, ascending=False).index.values
        both = find_intersection(df.index.values, idxb, pick_from)
        keep = df.loc[both, :].sample(1)
        pid = keep.index.values[0]    
        
    #output text to show our results
    match_text = 'Profile number ' + str(pid)
    match_text += ' has more of topic ' + str(topic_a)
    match_text += ' than {:.2f}%'.format(100 - (np.where(df.index==pid)[0][0] / n)*100)
    match_text += ' of other profiles'
    if topic_b is not None:
        match_text += ' and more of topic ' + str(topic_b)
        match_text += ' than {:.2f}%'.format(100 - (np.where(idxb==pid)[0][0] / n)*100)
        match_text += ' of other profiles.'
        
    #print results
    text = data[pid]
    print(match_text)
    print('Here is the text:\n\n', text)
    return

def visualize_profile(profile_topics, profile_id):
    # plot a stem diagram for a single profile
    plt.figure(figsize=(8,4))
    plt.xticks(range(profile_topics.shape[1]))
    plt.xlabel('Topic number')
    plt.ylabel('How much of profile is about each topic')
    plt.title('Profile #'+str(profile_id))
    plt.stem(profile_topics[profile_id,:])
    #plt.savefig()
    return

# %% [markdown]
# #### Calculate what portion of each profile is about each topic

# %%
profile_topics = lda.transform(tf_text)

# %% [markdown]
# #### Look at the text of a profile that has a lot of a particular topic
# - This function randomly picks one of the top few profiles for a topic, so each time you run it you will see a different example.
#     - If you want it to pick from more or less topics, change the value of `pick_from`
#     - If you want to see a different topic, change the value of `topic_a`
#     - **Hint:** you can press `ctrl`+`enter` over and over to keep re-running the code in this cell.

# %%
get_profiles_from_topics(profiles['essay0'], profile_topics, topic_a=8, pick_from=20)
# Out:
# Profile number 15628 has more of topic 8 than 99.93% of other profiles
# Here is the text:
#
#  easy going guy trying to let things flow

# %% [markdown]
# #### Look at the text of a profile that matches two topics well at the same time
# - Note that some topics might not happen together very often. If this is the case, the examples we find of both together might not be very good.

# %%
get_profiles_from_topics(profiles['essay0'], profile_topics, topic_a=1, topic_b=2)
# Out:
# Profile number 17754 has more of topic 6 than 93.01% of other profiles and more of topic 2 than 91.43% of other profiles.
# Here is the text:
#
#  i am a warm and sincere person who believes in a strong intimate connection with the right woman i am reliable and can be counted on in a pinch i have a lot of relationship experience and know how to be with awoman i believe in sinfulness and loving kindness and so must my partner

# %% [markdown]
# #### See how much of a profile is about each topic
# - Try looking at some of the profiles you just found:
#     - Make the `pid` equal to the profile number from above.

# %%
pid =109
visualize_profile(profile_topics, profile_id=pid)

# %%
pid =90
visualize_profile(profile_topics, profile_id=pid)

# %% [markdown]
# ## Section 5: Topic Quality
# Let's see how good the topics we found are.
#
# ### Step 1: See if the topics are each about different things.
# We want each topic to be about something different than the other topics. We can check this by comparing the words in each topic to the words in all the others. How to interpret:
# - Each square shows how similar two topics are. Darker means more similar, and lighter means more different.
# - The square in the very top left shows how similar topic 0 is to topic 0 (i.e. how similar it is to itself).
# - The square next to it in the top row shows how similar topic 0 is to topic 1, and so on.
# - For any two topics, you can see how similar they are by finding their numbers on the edges and seeing where they intersect.

# %%
def plot_topics(components):
    sim = cosine_similarity(components)
    blue_matrix(sim, xl='Topic number', yl='Topic number')
    
    return

plot_topics(lda_topics)

# %% [markdown]
# ### Step 2: See if different topics show up in different profiles
# The point is to tell profiles apart based on what topics they're about, so we need to check whether the topics appear in different profiles.
# - This shows us something that looks similar to the topic similarity we saw before, but this time:
#     - We **don't** compare topics based on which words they use
#     - We **do** compare topics based on how often they appear in the same profile as one another

# %%
def topic_cooccurance(topics):
    co = pd.DataFrame(topics).corr()
    blue_matrix(co, xl='Topic number', yl='Topic number')

topic_cooccurance(profile_topics)

# %% [markdown]
# #### Note that the topics are mostly uncorrelated.
# - The cells in the figure above are mostly very light blue
# - This doesn't mean that, for instance, topic 1 and 2 never show up in the same profile.
# - It does mean, however, that seeing any particular topic doesn't mean we're especially likely to also see any other topic.
#
# #### Reflect:
# - Why is the diagonal line so dark? Write a sentence or two.

# %% [markdown]
# **Write your response here:**
# ....

# %% [markdown]
# ## Section 6: Topic Popularity
#
# #### Helper functions to visualize and compare topics
# - Run this code and scroll down. The details of how it works aren't our focus right now.

# %%
def common_topics_bars(topics):
    popularity = pd.DataFrame(topics).mean()
    popularity = popularity.rename_axis('Topic')
    popularity = popularity.sort_values(ascending=False)
    popularity.plot.bar(title='Topic popularity')
    plt.savefig('barplot.png')
    return

def rank_groups(data, trait, topic):
    groups = data[trait].value_counts().index.values
    result = {}
    
    for g in groups:
        result[g] = data[data[trait] == g][topic].mean()
    
    r = pd.DataFrame.from_dict(result, orient='index')
    r.columns = [topic]
    r = r.sort_values(by=topic, ascending=False)
    
    return r.round(3)

def top_topics(data, trait, value, n_top_topics=3, distinctive=False):
    topics = [col for col in data if col.startswith('topic_')]
    vals = {}
    means = {}
    if distinctive:
        for t in topics:
            means[t] = data[t].mean()
    else:
        for t in topics:
            means[t] = 1
    
    data = data[data[trait] == value]
    
    for t in topics:
        vals[t] = data[t].mean() / means[t]
    vals = pd.DataFrame.from_dict(vals, orient='index')    
    vals = vals.sort_values(by=0, ascending=False).head(n_top_topics)

    return list(vals.index.values)

# %% [markdown]
# ### Overall most common topics

# %%
common_topics_bars(profile_topics)

# %% [markdown]
# ### Who is a topic most popular with?

# %% [markdown]
# #### Step 1: Merge our information about topics with our information about people

# %%
topic_info = pd.DataFrame(profile_topics).add_prefix('topic_')
together = profiles.merge(topic_info, left_index=True, right_index=True)
together.to_csv('topic_profiles_9.csv')

# %%
short= together['height_group']=='short'
short_folks = together[short]
short_prop= short_folks.iloc[:,-9:-1]
# Out:
#         topic_0   topic_1   topic_2   topic_3   topic_4   topic_5   topic_6  \
# 2      0.001711  0.264565  0.286345  0.001710  0.354685  0.001710  0.001711
# 3      0.002417  0.173317  0.141929  0.002416  0.002417  0.002416  0.563404
# 8      0.005851  0.005852  0.382065  0.251084  0.005850  0.005852  0.005852
# 13     0.037058  0.703591  0.037061  0.037037  0.037084  0.037039  0.037046
# 17     0.015878  0.015903  0.015886  0.015881  0.015890  0.015880  0.307486
# 20     0.002527  0.002528  0.896662  0.085653  0.002526  0.002526  0.002526
# 21     0.004116  0.169035  0.004119  0.004117  0.540002  0.004117  0.004120
# 22     0.121717  0.368794  0.344720  0.009260  0.009260  0.009261  0.118463
# 27     0.001565  0.019686  0.442938  0.001567  0.219205  0.079694  0.232213
# 28     0.098192  0.539702  0.137969  0.086819  0.001222  0.077185  0.001222
# 30     0.002317  0.002317  0.002317  0.002316  0.747694  0.002316  0.236090
# 31     0.125151  0.002780  0.380210  0.002779  0.174400  0.002780  0.103906
# 36     0.010103  0.010111  0.919157  0.010103  0.010103  0.010102  0.010105
# 39     0.198576  0.018528  0.424751  0.018520  0.018524  0.265529  0.018533
# 43     0.011116  0.605055  0.011115  0.011112  0.011116  0.011112  0.317138
# 45     0.001278  0.196871  0.143328  0.028233  0.064194  0.303294  0.001278
# 47     0.001793  0.210559  0.273114  0.001794  0.001793  0.188792  0.149336
# 51     0.001822  0.001823  0.152086  0.001823  0.120045  0.074848  0.001822
# 52     0.650444  0.003970  0.182215  0.143517  0.003972  0.003971  0.003971
# 53     0.001611  0.001612  0.219085  0.142853  0.365505  0.001612  0.264500
# 56     0.105881  0.270409  0.001567  0.001567  0.001566  0.001566  0.359390
# 62     0.834010  0.002022  0.151839  0.002021  0.002021  0.002024  0.002021
# 64     0.003972  0.603745  0.368463  0.003972  0.003970  0.003968  0.003970
# 65     0.002711  0.754284  0.002711  0.002711  0.002711  0.002711  0.002711
# 67     0.000942  0.821107  0.172298  0.000942  0.000942  0.000942  0.000942
# 70     0.000959  0.485612  0.077058  0.000958  0.172207  0.060213  0.159069
# 71     0.001101  0.207160  0.101744  0.154461  0.203323  0.001101  0.001101
# 73     0.006946  0.308735  0.006951  0.642626  0.006949  0.006948  0.006947
# 74     0.060178  0.021981  0.453100  0.001059  0.001059  0.060664  0.242268
# 77     0.015880  0.465365  0.423490  0.015884  0.015875  0.015874  0.015882
# ...         ...       ...       ...       ...       ...       ...       ...
# 18738  0.001822  0.171081  0.326609  0.026367  0.001824  0.001823  0.001823
# 18742  0.006175  0.006177  0.514634  0.330982  0.006177  0.006173  0.006177
# 18744  0.073969  0.002648  0.002646  0.002647  0.027843  0.299005  0.218835
# 18746  0.000662  0.072259  0.351874  0.143726  0.000662  0.167124  0.218380
# 18748  0.004632  0.004633  0.365550  0.304286  0.004631  0.004631  0.302372
# 18752  0.004118  0.004118  0.301534  0.004118  0.004116  0.088099  0.440304
# 18754  0.018524  0.018528  0.851774  0.018536  0.018526  0.018519  0.018524
# 18755  0.168507  0.002367  0.130145  0.002366  0.002365  0.002365  0.418214
# 18756  0.060287  0.002269  0.576773  0.243792  0.002269  0.002270  0.002269
# 18760  0.005052  0.485980  0.005053  0.096682  0.005051  0.005053  0.147974
# 18761  0.159552  0.004832  0.004832  0.004835  0.196223  0.004833  0.004832
# 18762  0.021866  0.256284  0.234645  0.249961  0.157658  0.001523  0.075017
# 18766  0.369670  0.132094  0.294922  0.003474  0.003475  0.003476  0.003475
# 18767  0.144451  0.136099  0.090556  0.146946  0.335065  0.140467  0.002139
# 18768  0.002138  0.567015  0.374510  0.002139  0.002138  0.002137  0.002138
# 18772  0.216655  0.002416  0.036833  0.068169  0.179097  0.074019  0.211328
# 18775  0.263784  0.001209  0.335566  0.187033  0.001208  0.025608  0.067521
# 18779  0.002585  0.002586  0.610663  0.002584  0.002586  0.224422  0.002585
# 18781  0.255278  0.001566  0.044711  0.250003  0.159253  0.058374  0.227683
# 18783  0.043695  0.081864  0.209264  0.001356  0.268556  0.001356  0.068871
# 18786  0.005558  0.005557  0.005557  0.005558  0.005557  0.005556  0.495634
# 18788  0.002316  0.236791  0.317362  0.002316  0.310214  0.002317  0.086216
# 18793  0.002926  0.002927  0.202329  0.002927  0.288293  0.002926  0.201804
# 18796  0.001249  0.069425  0.439409  0.163880  0.001249  0.001249  0.269855
# 18797  0.006946  0.231052  0.006951  0.205405  0.006947  0.006948  0.521848
# 18799  0.002417  0.037780  0.002417  0.194744  0.002416  0.002416  0.555727
# 18800  0.006173  0.184200  0.006177  0.198347  0.006173  0.006173  0.315594
# 18804  0.002316  0.085855  0.097958  0.002317  0.250850  0.040643  0.002317
# 18805  0.001951  0.047622  0.001950  0.136393  0.166328  0.266829  0.108774
# 18812  0.007409  0.616059  0.007412  0.007412  0.256337  0.083142  0.007409
#
#         topic_7
# 2      0.001711
# 3      0.002416
# 8      0.193681
# 13     0.037042
# 17     0.581320
# 20     0.002527
# 21     0.004117
# 22     0.009262
# 27     0.001566
# 28     0.056467
# 30     0.002317
# 31     0.002780
# 36     0.010103
# 39     0.018519
# 43     0.011120
# 45     0.001278
# 47     0.079909
# 51     0.447109
# 52     0.003971
# 53     0.001611
# 56     0.001566
# 62     0.002021
# 64     0.003970
# 65     0.002711
# 67     0.000942
# 70     0.000958
# 71     0.328908
# 73     0.006951
# 74     0.001059
# 77     0.015876
# ...         ...
# 18738  0.001822
# 18742  0.006175
# 18744  0.002646
# 18746  0.044650
# 18748  0.004632
# 18752  0.004118
# 18754  0.018523
# 18755  0.036411
# 18756  0.107802
# 18760  0.244102
# 18761  0.004832
# 18762  0.001523
# 18766  0.003475
# 18767  0.002138
# 18768  0.045647
# 18772  0.209065
# 18775  0.116862
# 18779  0.002585
# 18781  0.001566
# 18783  0.116247
# 18786  0.005559
# 18788  0.040152
# 18793  0.292942
# 18796  0.052435
# 18797  0.006949
# 18799  0.002417
# 18800  0.006177
# 18804  0.078018
# 18805  0.268203
# 18812  0.007412
#
# [6616 rows x 8 columns]

# %%
common_topics_bars(short_prop)

# %% [markdown]
# #### Step 2: See the groups that have the most text about a given topic
# - The numbers here show how much of a profile, on average, is about a specific topic.
#
# #### Play around with the code in the next few cells:
# - Pick one of the traits we have data for. Here are the options (information we know about users from their profiles):
#     - `age_group` categories: ['10', '20', '30', '40', '50']
#     - `body` categories: ['average', 'fit', 'thin', 'overweight', 'unknown']
#     - `alcohol_use` categories: ['yes', 'no']
#     - `drug_use` categories: ['yes', 'no']
#     - `edu` (highest degree completed) categories: ['`<HS`', 'HS', 'BA', 'Grad_Pro', 'unknown']
#     - `race_ethnicity` categories: ['Asian', 'Black', 'Latinx', 'White', 'multiple', 'other']
#     - `height_group` (whether someone is over or under six feet tall) categories: ['under_6', 'over_6']
#     - `industry` (what field they work in) categories: ['STEM', 'business', 'education', 'creative', 'med_law', 'other']
#     - `kids` (whether they have children) categories: ['yes', 'no']
#     - `orientation` categories: ['straight', 'gay', 'bisexual']
#     - `pets_likes` (what pets they like) categories: ['both', 'dogs', 'cats', 'neither']
#     - `pets_has` (what pets they have) categories: ['both', 'dogs', 'cats', 'neither']
#     - `pets_any` (whether they have pets or not) categories: ['yes', 'no']
#     - `religion` categories: ['christianity', 'catholicism', 'judaism', 'buddhism', 'none', 'other']
#     - `sex` categories: ['m', 'f']
#     - `smoker` categories: ['yes', 'no']
#     - `languages` categories: ['multiple', 'English_only']
# - Change the topics and values in the code in the next few cells to explore how the trait you chose relates to the topics.
#
# #### Short Answer:
# - Write down which trait(s) you chose to look at, and what you learned about different groups of people from the topics they used. What topics do they have in common? What topics make them different? Does this make sense given the groups? Why or why not? Remember: we interpreted the topics above, so explain your findings in terms of content, not just topic numbers. Write 1-2 paragraphs.

# %%
rank_groups(together, trait='edu', topic='topic_0')
# Out:
#                        topic_0
# High School or less      0.110
# unknown                  0.093
# More than High School    0.058

# %% [markdown]
# #### Step 3: See the topics that are most common for a given group
# - This example shows most common topics for different education groups.
# - You can change the arguments to compare different groups.

# %%
#show most popular topics for High School graduates
def create_top_six():
    """
    takes in a df and a list of categorical variables
    create dataframe out of 
    """
    pass

top_six = {}
traits = ['edu']

for _trait in traits:
    trait_dict = {}
    uniques = profiles[_trait].unique()
    for val in uniques:
        col = top_topics(data=together, trait=_trait, value=val, n_top_topics=7)
        trait_dict[val] = col

# %%
race_traits= pd.DataFrame(trait_dict)

# %%
race_traits = race_traits.transpose()

# %%
race_traits
# Out:
#                              0        1        2        3        4        5  \
# High School or less    topic_2  topic_1  topic_6  topic_0  topic_8  topic_4
# More than High School  topic_2  topic_6  topic_1  topic_8  topic_5  topic_4
# unknown                topic_2  topic_1  topic_6  topic_8  topic_0  topic_3
#
#                              6
# High School or less    topic_3
# More than High School  topic_3
# unknown                topic_4

# %%
#show most popular topics for High School graduates
top_topics(data=together, trait='edu', value='BA', n_top_topics=3)
# Out:
# ['topic_0', 'topic_1', 'topic_2']

# %% [markdown]
# #### Step 4: See the topics that distinguish a group from other groups
# - This example shows most distinctive topics for different education levels.
# - You can change the arguments to compare different groups

# %%
top_topics(data=together, trait='edu', value='HS', n_top_topics=3, distinctive=True)
# Out:
# ['topic_0', 'topic_1', 'topic_2']

# %%
top_topics(data=together, trait='edu', value='Grad_Pro', n_top_topics=3, distinctive=True)
# Out:
# ['topic_0', 'topic_1', 'topic_2']

# %% [markdown]
# **Write your response here:**
# ....

# %% [markdown]
# # Section 7: NMF Topic Model
# - NMF is an alternative to LDA
# - NMF stands for Non-Negative Matrix Factorization.

# %% [markdown]
# ### Expand for more on how NMF works

# %% [markdown]
# - `Factoring` is something you may have done in math class before, for example:
#     - $ 10 $ can be factored as $ 2 \times 5 $
#     - $ x^2+3x+2 $ can be factored as $ (x+2)(x+1)$
# - When we convert the text into numbers for the computer, it gets stored as something called a `matrix`.
#     - The matrix is `non-negative` because we can't have negative numbers of words: all the word counts are zero or more.
# - It is not important right now how exactly we find factors for these matrices, but if you're curious, you can learn more about it in a Linear Algebra class.
# - It turns out that finding factors for text is a really good way of finding topics. This makes sense intuitively: factors are simple things we can combine to get the more complicated output, and topics are simple things people combine to write profiles.
# - [Learn more](https://en.wikipedia.org/wiki/Non-Negative_matrix_factorization#Text_mining) about NMF.

# %% [markdown]
# ### Step 1: Convert text to numbers the computer understands
# - NMF takes "tf-idf vectors" as input. Tf-idf stands for "text frequency - inverse document frequency."
#     - Text frequency is the same as the count vectors we used for LDA above: how often does each word appear in the text?
#     - Inverse document frequency means we divide ("inverse") by the number of documents the word is in. (If everyone uses the word, it isn't very helpful for figuring out what makes people different. So this measurement looks for words that are used a lot in some documents, and not at all in others.)

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=2000, stop_words='english', ngram_range=(1,3))

print("Vectorizing text by TF-IDF...")
tfidf_text = tfidf_vectorizer.fit_transform(documents)

tmp = tfidf_text.get_shape()
print("Our transformed text has", tmp[0], "rows and", tmp[1], "columns.")
# Out:
# Vectorizing text by TF-IDF...
# Our transformed text has 18817 rows and 2000 columns.

# %% [markdown]
# #### The features are mostly the same as count vectors, because they are just the common words in the text

# %%
tfidf_words = tfidf_vectorizer.get_feature_names()
print("The first few words (alphabetically) are:\n", tfidf_words[:20])
# Out:
# The first few words (alphabetically) are:
#  ['10', '10 years', '100', '12', '15', '20', '23', '25', '30', '500', 'ability', 'able', 'abroad', 'absolutely', 'absolutely love', 'absurd', 'accent', 'accept', 'achieve', 'act']

# %% [markdown]
# #### The values are different: the counts have been divided by the documents they show up in

# %%
n = 4

print('Profile text:\n', documents[n])
print('\nTF-IDF vector:')
show_vector(tfidf_text[n], words=tfidf_words)
# Out:
# Profile text:
#  i was born in wisconsin grew up in iowa and moved to california three years ago for a combination of work opportunity and just wanting to live in sf it took me a couple years to get to the peninsula but i'm glad i eventually got here i'm passionate about people and have a wide variety of interests and talentsi'm also continually learning about myself for example i'mlearning very recently that as a result of spending all my time growing up in college and for the last five years focusing on growing my deep relationship skills i'm not as good as i previously thought at initializing friendships relationships i guess that isn't all a bad thing since the first impression thing only really happens once with each person as a result i love my friends i've got a lot of deep friendships and know how much richer a friendship can get as it getsdeeperi'm passionate about music i play the guitar write songs less now than before write plays more now than before want to learn french and asl am pretty good for an amateur ballroom dancer can do almost everything moderately well seriously no joke love bright ties and shoes am a jacket and jeans person and absolutely love figuring out how people tick i think i'm pretty cool and wish more people would be patient enough to take the time to see that every friend i've ever had say i'm nothing like anyone else so idon't come off like anyone else i'm my own person and i'm proud of that
#
# TF-IDF vector:
# love 	 0.11
# think 	 0.06
# say 	 0.06
# like 	 0.07
# friend 	 0.08
# know 	 0.05
# got 	 0.15
# shoes 	 0.12
# really 	 0.05
# deep 	 0.18
# work 	 0.05
# cool 	 0.08
# just 	 0.04
# good 	 0.09
# songs 	 0.12
# pretty 	 0.12
# people 	 0.13
# sf 	 0.07
# live 	 0.06
# years 	 0.16
# music 	 0.06
# play 	 0.06
# guitar 	 0.09
# ve 	 0.11
# play guitar 	 0.11
# ve got 	 0.1
# born 	 0.07
# grew 	 0.07
# moved 	 0.06
# california 	 0.08
# ago 	 0.08
# opportunity 	 0.1
# wanting 	 0.12
# took 	 0.1
# couple 	 0.09
# eventually 	 0.11
# passionate 	 0.15
# wide 	 0.11
# variety 	 0.11
# interests 	 0.08
# learning 	 0.08
# example 	 0.12
# recently 	 0.07
# result 	 0.24
# spending 	 0.09
# time 	 0.09
# growing 	 0.2
# college 	 0.07
# relationship 	 0.08
# skills 	 0.11
# thought 	 0.09
# friendships 	 0.24
# relationships 	 0.09
# guess 	 0.08
# isn 	 0.1
# bad 	 0.08
# thing 	 0.14
# happens 	 0.11
# person 	 0.17
# friends 	 0.05
# lot 	 0.06
# friendship 	 0.11
# write 	 0.17
# plays 	 0.12
# want 	 0.06
# learn 	 0.08
# french 	 0.11
# seriously 	 0.08
# joke 	 0.1
# bright 	 0.12
# jeans 	 0.12
# absolutely 	 0.11
# figuring 	 0.12
# wish 	 0.1
# patient 	 0.11
# idon 	 0.11
# come 	 0.08
# proud 	 0.11
# moved california 	 0.12
# years ago 	 0.09
# couple years 	 0.11
# spending time 	 0.1
# pretty good 	 0.11
# absolutely love 	 0.12

# %% [markdown]
# ### Step 2: Build a topic model using NMF
#
# - NMF is faster than LDA and often works a little better for small documents like we have here.

# %%
model = NMF(n_components=ntopics, alpha=.1, l1_ratio=.5, init='nndsvd', random_state=seed)

print('Performing NMF on vectors...')
nmf = model.fit(tfidf_text)
nmf_topics = nmf.components_

print('Done!')
# Out:
# Performing NMF on vectors...
# Done!

# %%
nmf_filename = 'nmf_model.sav'
pickle.dump(model, open(nmf_filename, 'wb'))

# %%
nmf_profile_topics= nmf.transform(tfidf_text)

# %%
nmf_topic_info = pd.DataFrame(nmf_profile_topics).add_prefix('topic_')
nmf_together = profiles.merge(nmf_topic_info, left_index=True, right_index=True)
nmf_together.to_csv('nmf_topics_profiles.csv')

# %% [markdown]
# ### Step 3: Show our topics with the top words in each

# %% [markdown]
# display_topics(nmf_topics, tfidf_words, nshow)

# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

# %%
pyLDAvis.sklearn.prepare(final_ls, corpus, dictionary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-188-c6802df563ad> in <module>()
# ----> 1 pyLDAvis.sklearn.prepare(final_ls, corpus, dictionary)
#
# NameError: name 'final_ls' is not defined

# %% [markdown]
# ### Step 4: Compare topics to each other
# We can compare topics visually by plotting the similarity of each topic's chosen words to each other topic.

# %% [markdown]
# get_profiles_from_topics(profiles['essay0'], nmf_profile_topics, topic_a=11, topic_b=12)

# %%
nmf_profile_topics.shape
# Out:
# (18817, 9)

# %%
common_topics_bars(nmf_profile_topics)

# %%
plot_topics(nmf_profile_topics)

# %%
topic_cooccurance(nmf_profile_topics)

# %%
topic_cooccurrance(lda_topics)

# %%
top_topics(data=nmf_together, trait='race_ethnicity', value='Latinx', n_top_topics=7)

# %% [markdown]
# #### Examine the words that make two topics similar or different
# We can also compare two topics to each other by looking at words that are common in both, or words that are common in one but not the other. Try changing topic_a and topic_b to different topic numbers.

# %%
topic_a = 3
topic_b = 21

compare_topic_words(nmf_topics, topic_a, topic_b, tfidf_words, n_words=nshow, how='overlap')
compare_topic_words(nmf_topics, topic_a, topic_b, tfidf_words, n_words=nshow, how='difference')
compare_topic_words(nmf_topics, topic_b, topic_a, tfidf_words, n_words=nshow, how='difference')

# %% [markdown]
# ### Step 5: Interpret these topics
# - This part is for you to do: code can't do it for you.
# - Look at the list of important words for each topic, and think about these questions. (No writing required.)
#     - What do the words have in common?
#     - What could someone write that would use most of those words?
#     - What does this topic seem to be about?
# - Try to come up with a short, catchy name for each topic.
#     - For example, if the words were "san francisco city moved living born years raised lived live", you might call it "places lived" because the topic seems to be about where people currently live (San Francisco) and where they were born / raised / moved from.
# - Try other numbers of topics.
#     - If the topics seem repetitive, you might want to try looking for fewer topics.
#     - If the topics seem confusing or vague, you might want to try looking for more topics (so that they can be more specific).

# %% [markdown]
# ### Step 6: Compare the topics from LDA and NMF
#
# #### Helper function to make a graph for us

# %%
def plot_confusion(x, y, x_label='', y_label='', sort=True):
    n = x.shape[0]
    corrs = cosine_similarity(x, y)
    topic_similarity = pd.DataFrame(corrs)
    new_order=None
    
    if sort:
        matches = []
        pairs = {}

        for i in range(n):
            for j in range(n):
                tmp = {}
                tmp['i'] = i
                tmp['j'] = j
                tmp['match'] = corrs[i][j]
                matches.append(tmp)

        matches = pd.DataFrame(matches).sort_values(by='match', ascending=False)

        for row in matches.iterrows():
            i = row[1]['i']
            j = row[1]['j']
            if i not in pairs.keys():
                if j not in pairs.values():
                    pairs[i] = row[1]['j']

        new_order = list(range(n))
        for k in pairs.keys():
            new_order[int(k)] = int(pairs[k])

        topic_similarity = topic_similarity[new_order]

    blue_matrix(topic_similarity, xl=x_label, yl=y_label,
                x_labels=new_order)
    return

# %% [markdown]
# #### See how similar the words in each topic from LDA are to the words in each topic from NMF
# - The NMF topics are along the X axis and the LDA are along the Y axis.

# %%
plot_confusion(x = nmf_topics, x_label='NMF topic number',
               y = lda_topics, y_label='LDA topic number',
               sort=False)

# %% [markdown]
# #### We can also sort the topics so that the most similar ones are aligned

# %%
plot_confusion(x = nmf_topics, x_label='NMF topic number',
               y = lda_topics, y_label='LDA topic number',
               sort=True)

# %% [markdown]
# Look at the LDA and NMF topic words and the confusion matrix, and consider the following questions (no writing required):
# - Do any of the topics seem to be the same in both models?
# - Are some topics in one model but not the other?
# - Do the topics you get from one of the models make more sense than the ones you get from the other?

# %% [markdown]
# ## Section 8: What We Learned
# - Two statistical methods for topic modeling
#     - LDA
#     - NMF
# - Two ways to represent text as numbers
#     - TF / count vectors (counts of how often each word is used)
#     - TF-IDF vectors (counts of how often each word is used, divided by the number of documents they're used in)
# - How to think about and interpret the topics our models find
# - How to compare and relate different topics
# - Different ways to see the distribution of topics in profiles
# - Which topics are most popular with social categories of people
# - Which social categories of people discuss a topic most

# %% [markdown]
# #### Reflect
# - How is what we learned in this lab, using topic modeling, different from what we learned in the last lab, using just word frequencies? How is it similar? Write a paragraph explaining.

# %% [markdown]
# **Write your response here:**
# ....
